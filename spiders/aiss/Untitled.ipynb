# %%
    start_urls = ['http://api.pmkoo.cn/']
    params = {'page': '13', 'userId': '153044'}
    name = 'mm'
    url = 'http://api.pmkoo.cn/aiss/suite/suiteList.do'

# %%
# !pip install requests
# Out:
# Collecting requests
#   Downloading http://mirrors.aliyun.com/pypi/packages/49/df/50aa1999ab9bde74656c2919d9c0c085fd2b3775fd3eca826012bef76d8c/requests-2.18.4-py2.py3-none-any.whl (88kB)
#     100% |████████████████████████████████| 92kB 205kB/s ta 0:00:01
# Collecting idna<2.7,>=2.5 (from requests)
#   Downloading http://mirrors.aliyun.com/pypi/packages/27/cc/6dd9a3869f15c2edfab863b992838277279ce92663d334df9ecf5106f5c6/idna-2.6-py2.py3-none-any.whl (56kB)
#     100% |████████████████████████████████| 61kB 214kB/s ta 0:00:01
# Collecting urllib3<1.23,>=1.21.1 (from requests)
#   Downloading http://mirrors.aliyun.com/pypi/packages/63/cb/6965947c13a94236f6d4b8223e21beb4d576dc72e8130bd7880f600839b8/urllib3-1.22-py2.py3-none-any.whl (132kB)
#     100% |████████████████████████████████| 133kB 198kB/s ta 0:00:01
# Collecting certifi>=2017.4.17 (from requests)
#   Downloading http://mirrors.aliyun.com/pypi/packages/40/66/06130724e8205fc8c105db7edb92871c7fff7d31324d7f4405c762624a43/certifi-2017.7.27.1-py2.py3-none-any.whl (349kB)
#     100% |████████████████████████████████| 358kB 213kB/s ta 0:00:01
# Collecting chardet<3.1.0,>=3.0.2 (from requests)
#   Downloading http://mirrors.aliyun.com/pypi/packages/bc/a9/01ffebfb562e4274b6487b4bb1ddec7ca55ec7510b22e4c51f14098443b8/chardet-3.0.4-py2.py3-none-any.whl (133kB)
#     100% |████████████████████████████████| 143kB 220kB/s ta 0:00:01
# Installing collected packages: idna, urllib3, certifi, chardet, requests
# Successfully installed certifi-2017.7.27.1 chardet-3.0.4 idna-2.6 requests-2.18.4 urllib3-1.22

# %%
import requests

# %%
r = requests.post(url=url, data=params)

# %%
r.status_code
# Out:
# 200

# %%
r.json().get('data').get('list')
# Out:
# [{'author': {'area': '北京',
#    'birthday': '1993-01-15',
#    'bwh': '91-52-90',
#    'headerUrl': 'XiaoSi.jpg',
#    'height': '168',
#    'id': 100190,
#    'nickname': '小丝',
#    'sex': 2,
#    'weight': '53'},
#   'authorId': 100190,
#   'createTime': 1503159358000,
#   'favorite': False,
#   'favoriteCount': 195,
#   'headImageFilename': '14.jpg',
#   'id': 1305,
#   'issue': 203,
#   'level': 3,
#   'pictureCount': 20,
#   'source': {'catalog': 'playboy',
#    'hearderImagePath': None,
#    'id': 9,
#    'lastSuiteId': 0,
#    'name': 'Playboy',
#    'pictureCount': 0,
#    'suiteCount': 0},
#   'sourceId': 9,
#   'title': 'Come to Bed',
#   'vip': 1},
#  {'author': {'area': '北京',
#    'birthday': '1994-01-05',
#    'bwh': '86-63-86',
#    'headerUrl': 'YuSiQi.jpg',
#    'height': '170',
#    'id': 102366,
#    'nickname': '于思琪',
#    'sex': 2,
#    'weight': '51'},
#   'authorId': 102366,
#   'createTime': 1503159006000,
#   'favorite': False,
#   'favoriteCount': 600,
#   'headImageFilename': '7.jpg',
#   'id': 1304,
#   'issue': 214,
#   'level': 1,
#   'pictureCount': 24,
#   'source': {'catalog': 'ugirls',
#    'hearderImagePath': None,
#    'id': 8,
#    'lastSuiteId': 0,
#    'name': '尤果网',
#    'pictureCount': 0,
#    'suiteCount': 0},
#   'sourceId': 8,
#   'title': '美食真是一种享受',
#   'vip': 1},
#  {'author': {'area': '长沙',
#    'birthday': '1994-03-25',
#    'bwh': '90-65-91',
#    'headerUrl': 'CaiWenYu.jpg',
#    'height': '160',
#    'id': 191759,
#    'nickname': '蔡文钰',
#    'sex': 2,
#    'weight': '49'},
#   'authorId': 191759,
#   'createTime': 1503158739000,
#   'favorite': False,
#   'favoriteCount': 268,
#   'headImageFilename': '12.jpg',
#   'id': 1303,
#   'issue': 214,
#   'level': 2,
#   'pictureCount': 22,
#   'source': {'catalog': 'xiuren',
#    'hearderImagePath': None,
#    'id': 7,
#    'lastSuiteId': 0,
#    'name': '秀人网',
#    'pictureCount': 0,
#    'suiteCount': 0},
#   'sourceId': 7,
#   'title': '大连真的不错',
#   'vip': 1},
#  {'author': {'area': '长沙',
#    'birthday': '1994-03-25',
#    'bwh': '90-65-91',
#    'headerUrl': 'CaiWenYu.jpg',
#    'height': '160',
#    'id': 191759,
#    'nickname': '蔡文钰',
#    'sex': 2,
#    'weight': '49'},
#   'authorId': 191759,
#   'createTime': 1503072942000,
#   'favorite': False,
#   'favoriteCount': 278,
#   'headImageFilename': '23.jpg',
#   'id': 1302,
#   'issue': 214,
#   'level': 1,
#   'pictureCount': 24,
#   'source': {'catalog': 'mygirl',
#    'hearderImagePath': None,
#    'id': 6,
#    'lastSuiteId': 0,
#    'name': '美媛馆',
#    'pictureCount': 0,
#    'suiteCount': 0},
#   'sourceId': 6,
#   'title': '老司机，快上车',
#   'vip': 1},
#  {'author': {'area': '北京',
#    'birthday': '1993-01-15',
#    'bwh': '91-52-90',
#    'headerUrl': 'XiaoSi.jpg',
#    'height': '168',
#    'id': 100190,
#    'nickname': '小丝',
#    'sex': 2,
#    'weight': '53'},
#   'authorId': 100190,
#   'createTime': 1503072604000,
#   'favorite': False,
#   'favoriteCount': 399,
#   'headImageFilename': '4.jpg',
#   'id': 1301,
#   'issue': 182,
#   'level': 3,
#   'pictureCount': 26,
#   'source': {'catalog': 'graphis',
#    'hearderImagePath': None,
#    'id': 4,
#    'lastSuiteId': 0,
#    'name': '日韩',
#    'pictureCount': 0,
#    'suiteCount': 0},
#   'sourceId': 4,
#   'title': '夢乃 あいか',
#   'vip': 1},
#  {'author': {'area': '北京',
#    'birthday': '1988-11-01',
#    'bwh': '65-55-75',
#    'headerUrl': 'ZhaoWeiYi.jpg',
#    'height': '167',
#    'id': 100001,
#    'nickname': '赵惟依',
#    'sex': 2,
#    'weight': '54'},
#   'authorId': 100001,
#   'createTime': 1503072339000,
#   'favorite': False,
#   'favoriteCount': 1656,
#   'headImageFilename': '6.jpg',
#   'id': 1300,
#   'issue': 115,
#   'level': 7,
#   'pictureCount': 20,
#   'source': {'catalog': 'tuigirl',
#    'hearderImagePath': None,
#    'id': 3,
#    'lastSuiteId': 0,
#    'name': '推女郎',
#    'pictureCount': 0,
#    'suiteCount': 0},
#   'sourceId': 3,
#   'title': '谁能帮我个忙呢',
#   'vip': 1},
#  {'author': {'area': '北京',
#    'birthday': '1993-01-15',
#    'bwh': '91-52-90',
#    'headerUrl': 'XiaoSi.jpg',
#    'height': '168',
#    'id': 100190,
#    'nickname': '小丝',
#    'sex': 2,
#    'weight': '53'},
#   'authorId': 100190,
#   'createTime': 1502986558000,
#   'favorite': False,
#   'favoriteCount': 397,
#   'headImageFilename': '0.jpg',
#   'id': 1299,
#   'issue': 202,
#   'level': 5,
#   'pictureCount': 24,
#   'source': {'catalog': 'playboy',
#    'hearderImagePath': None,
#    'id': 9,
#    'lastSuiteId': 0,
#    'name': 'Playboy',
#    'pictureCount': 0,
#    'suiteCount': 0},
#   'sourceId': 9,
#   'title': 'Bailey Rayne Flowerbed',
#   'vip': 1},
#  {'author': {'area': '重庆',
#    'birthday': '1995-02-14',
#    'bwh': '88-64-89',
#    'headerUrl': 'FangZiXuan.jpg',
#    'height': '174',
#    'id': 191758,
#    'nickname': '方子萱',
#    'sex': 2,
#    'weight': '50'},
#   'authorId': 191758,
#   'createTime': 1502986216000,
#   'favorite': False,
#   'favoriteCount': 335,
#   'headImageFilename': '4.jpg',
#   'id': 1298,
#   'issue': 213,
#   'level': 1,
#   'pictureCount': 20,
#   'source': {'catalog': 'ugirls',
#    'hearderImagePath': None,
#    'id': 8,
#    'lastSuiteId': 0,
#    'name': '尤果网',
#    'pictureCount': 0,
#    'suiteCount': 0},
#   'sourceId': 8,
#   'title': '失败乃成功之母',
#   'vip': 1},
#  {'author': {'area': '北京',
#    'birthday': '1992-10-27',
#    'bwh': '88-60-98',
#    'headerUrl': 'YouNaNa.jpg',
#    'height': '168',
#    'id': 191740,
#    'nickname': '尤娜娜',
#    'sex': 2,
#    'weight': '50'},
#   'authorId': 191740,
#   'createTime': 1502985917000,
#   'favorite': False,
#   'favoriteCount': 310,
#   'headImageFilename': '11.jpg',
#   'id': 1297,
#   'issue': 213,
#   'level': 2,
#   'pictureCount': 24,
#   'source': {'catalog': 'xiuren',
#    'hearderImagePath': None,
#    'id': 7,
#    'lastSuiteId': 0,
#    'name': '秀人网',
#    'pictureCount': 0,
#    'suiteCount': 0},
#   'sourceId': 7,
#   'title': '睡得昏天黑地的',
#   'vip': 1},
#  {'author': {'area': '杭州',
#    'birthday': '1991-10-08',
#    'bwh': '66-42-59',
#    'headerUrl': 'WangYuChun.jpg',
#    'height': '168',
#    'id': 100130,
#    'nickname': '王雨纯',
#    'sex': 2,
#    'weight': '47'},
#   'authorId': 100130,
#   'createTime': 1502900112000,
#   'favorite': False,
#   'favoriteCount': 359,
#   'headImageFilename': '3.jpg',
#   'id': 1296,
#   'issue': 213,
#   'level': 2,
#   'pictureCount': 28,
#   'source': {'catalog': 'mygirl',
#    'hearderImagePath': None,
#    'id': 6,
#    'lastSuiteId': 0,
#    'name': '美媛馆',
#    'pictureCount': 0,
#    'suiteCount': 0},
#   'sourceId': 6,
#   'title': '高速上一定要系安全套！',
#   'vip': 1}]
